# %%
import pandas as pd
import spacy
import nltk

# %%
df_chunk = pd.read_csv('data-Project5/books.csv', iterator=False, chunksize=1000)

# %%
df_chunk.get_chunk()
# Out:
#     marketplace  customer_id       review_id  product_id  product_parent  \
# 0            US     25933450   RJOVP071AVAJO  0439873800        84656342
# 1            US      1801372  R1ORGBETCDW3AI  1623953553       729938122
# 2            US      5782091   R7TNRFQAOUTX5  142151981X       678139048
# 3            US     32715830  R2GANXKDIFZ6OI  014241543X       712432151
# 4            US     14005703  R2NYB6C3R8LVN6  1604600527       800572372
# ..          ...          ...             ...         ...             ...
# 995          US     21073382  R1GT81BJMRCJA4  1118254368       710946003
# 996          US     44188391   R449Z4BWLQ4WH  1516928180       481202040
# 997          US     42397861  R3M75MJPYM033V  0763657697       320496701
# 998          US     52233305   R6VL1L0KDE5XZ  0871951762       630581469
# 999          US     15580431   R22RBFT0YGSCF  1939380154       317492720
#
#                                          product_title product_category  \
# ...

# %%
def chunk_preprocessing(chunk, cols):
    chunk = chunk[cols]
    return pd.DataFrame(chunk)

# %%
cols = ['review_id', 'review_date', 'product_title']
df = chunk_preprocessing(df_chunk.get_chunk(), cols)
df.head()
# Out:
#            review_id review_date  \
# 7000   RPTFT7I15WEI6  2015-08-31
# 7001   RWGUKTDH9GK4L  2015-08-31
# 7002  R1UYL6KRRIIZK0  2015-08-31
# 7003   ROK9DNPLMN9Z6  2015-08-31
# 7004   R7GO2SGVFH4EX  2015-08-31
#
#                                           product_title
# 7000      Bloodborne Collector's Edition Strategy Guide
# 7001  Inside Your Outside: All About the Human Body ...
# 7002  How Music Got Free: The End of an Industry  th...
# 7003                          Ghost Stories of Colorado
# 7004                          The Hunger Games (Book 1)

# %%
chunk_list = []
for chunk in df_chunk:  
    pp_chunk = chunk_preprocessing(chunk)
    chunk_list.append(pp_chunk)
df_concat = pd.concat(chunk_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b2e0e4ab390f> in <module>
#       1 chunk_list = []
# ----> 2 for chunk in df_chunk:
#       3     pp_chunk = chunk_preprocessing(chunk)
#       4     chunk_list.append(pp_chunk)
#       5 df_concat = pd.concat(chunk_list)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1126     def __next__(self):
#    1127         try:
# -> 1128             return self.get_chunk()
#    1129         except StopIteration:
#    1130             self.close()
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1186                 raise StopIteration
#    1187             size = min(size, self.nrows - self._currow)
# -> 1188         return self.read(nrows=size)
#    1189
#    1190
#
# ...
