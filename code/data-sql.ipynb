# %%
import pandas as pd
import numpy as np

# %%
filereader = pd.read_csv('books.csv', iterator=True, chunksize=1000)

# %%
import pandas.io.sql as pd_sql
from sqlalchemy import create_engine
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
from psycopg2 import connect

# %%
params = {
    'host': '35.184.195.154',
    'user': 'postgres',
    'port': 5432,
    'dbname': 'amazon',
    'password': 'Arun1810'
}

# sqlalchemy engine
sql_eng = create_engine('postgresql+psycopg2://',connect_args=params)

# connection
sql_conn = sql_eng.connect()

# %%
# Creating Schema
#pd_sql.to_sql(chunk, 'table', sql_conn.engine, if_exists='replace', index=False)

# %%
for _ in range(100):
    chunk = filereader.get_chunk()
    query = f'''
    COPY "books" FROM '{chunk}' DELIMITER ',';
    '''
    result = sql_conn.execute(query)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/opt/miniconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# SyntaxError: syntax error at or near "s"
# LINE 26: 107999                   The Murderer's Daughter: A Novel   ...
#                                                ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#copying files.
for _ in range(470,1725990):
    pd_sql.to_sql(chunk, 'reviews', sql_conn.engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/opt/miniconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# DatabaseError: SSL SYSCALL error: Operation timed out
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ...
